# %% [markdown]
# # Exercise 8: Data Cleaning and Analysis
#
# Welcome to Exercise 8!
#
# This exercise is a more free-form challenge than the previous ones you have completed. What I would like you to do is to demonstrate some of what you have learned in the previous exercises with another dataset.
#
# <img src="images/london2012.gif"/>
#
# First, by running the cell below we can display a sample of 25 rows from a CSV file containing records about athletes who competed in the London 2012 Olympics. This is a data set produced summarizing data prepared by the Guardian newspaper originally found [here](https://docs.google.com/spreadsheets/d/1CKSOQcrPDhxniv-V1FVFAo2rVXrguBCOFAsGZ_IwPJo/edit#gid=0).

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/djcomlab/olympics-graphs/master/london2012-olympics-v3.csv').sample(25)
# Out:
#                           Name                        Country  Age  \
# 2713               Ella Gunson                    New Zealand   23
# 8832          Sideris Tasiadis                        Germany   22
# 8544                Sasa Golob                       Slovenia   20
# 3881            Imogen Bankier                  Great Britain   24
# 10136           Yevgeniy Ektov                     Kazakhstan   25
# 5228            Klodiana Shala                        Albania   32
# 922                Anolyn Lulu                        Vanuatu   33
# 3213   Gabriel Melconian Alvez                        Uruguay   25
# 2570           Edzus Treimanis                         Latvia   24
# 9358       Thais Duarte Guedes                         Brazil   19
# 3649               Henri Ndong                          Gabon   19
# 9449                 Tim Veldt                    Netherlands   28
# 4409             Jessica Rossi                          Italy   20
# 7748         Pieter-Jan Postma                    Netherlands   30
# 9257           Tamsin Hinchley                      Australia   32
# 5300         Kristyna Palesova                 Czech Republic   21
# 1962    Courtney Carl Williams  St Vincent and the Grenadines   21
# 561                 Amit Kumar                          India   18
# 9773           Viktor Leptikov                     Kazakhstan   25
# 9095                 Storm Uru                    New Zealand   27
# 6491          Mc Kayla Maroney       United States of America   16
# 8137            Roberto Pavoni                  Great Britain   21
# 829                 Ankita Das                          India   19
# 6685                Mike Bryan       United States of America   34
# 5823             Lynne Beattie                  Great Britain   26
#
#        Height (cm)  Weight (kg) Sex Date of birth                  Sport  \
# 2713         162.0         62.0   F    07/09/1989                 Hockey
# 8832         179.0         79.0   M    05/07/1990           Canoe Slalom
# 8544         160.0          NaN   F     8/17/1991  Gymnastics - Artistic
# 3881         167.0         65.0   F    11/18/1987              Badminton
# 10136        187.0         75.0   M    09/01/1986              Athletics
# 5228           NaN          NaN   F     8/22/1979              Athletics
# 922          157.0         62.0   F    01/03/1979           Table Tennis
# 3213         182.0         74.0   M    07/07/1987               Swimming
# 2570         182.0         80.0   M     4/21/1988          Cycling - BMX
# 9358         164.0         60.0   F     1/20/1993               Football
# 3649         156.0         80.0   M     8/23/1992               Football
# 9449         186.0         78.0   M     2/14/1984        Cycling - Track
# 4409         168.0         57.0   F    01/07/1992               Shooting
# 7748         189.0        102.0   M    01/10/1982                Sailing
# 9257         193.0         74.0   F    03/10/1980       Beach Volleyball
# 5300         158.0          NaN   F     2/22/1991  Gymnastics - Artistic
# 1962         183.0         82.0   M     1/31/1991              Athletics
# 561            NaN          NaN   M    12/15/1993              Wrestling
# 9773         196.0         80.0   M    07/02/1987              Athletics
# 9095         190.0         72.0   M     2/14/1985                 Rowing
# 6491         160.0          NaN   F    12/09/1995  Gymnastics - Artistic
# 8137         176.0         71.0   M     3/22/1991               Swimming
# 829            NaN          NaN   F     7/17/1993           Table Tennis
# 6685         191.0         84.0   M     4/29/1978                 Tennis
# 5823         182.0         65.0   F    12/23/1985             Volleyball
#
#                                                    Event Medal winner? Gold  \
# 2713                                      Women's Hockey           NaN  NaN
# 8832                             Men's Canoe Single (C1)           YES  NaN
# 8544                               Women's Qualification           NaN  NaN
# 3881                                       Mixed Doubles           NaN  NaN
# 10136                                  Men's Triple Jump           NaN  NaN
# 5228                                        Women's 200m           NaN  NaN
# 922                                      Women's Singles           NaN  NaN
# 3213                                Men's 100m Freestyle           NaN  NaN
# 2570                                           Men's BMX           NaN  NaN
# 9358                                    Women's Football           NaN  NaN
# 3649                                      Men's Football           NaN  NaN
# 9449                                  Men's Team Pursuit           NaN  NaN
# 4409                                        Women's Trap           YES    1
# 7748                                          Men's Finn           NaN  NaN
# 9257                            Women's Beach Volleyball           NaN  NaN
# 5300                               Women's Qualification           NaN  NaN
# 1962                                          Men's 100m           NaN  NaN
# 561                                 Men's 55kg Freestyle           NaN  NaN
# 9773                                  Men's 400m Hurdles           NaN  NaN
# 9095                     Men's Lightweight Double Sculls           YES  NaN
# 6491                 Women's Team; Women's Qualification           YES  0.2
# 8137   Men's 200m Butterfly; Men's 400m Individual Me...           NaN  NaN
# 829                                      Women's Singles           NaN  NaN
# 6685                        Men's Doubles; Mixed Doubles           YES  0.5
# 5823                                  Women's Volleyball           NaN  NaN
#
#       Silver  Bronze
# 2713     NaN     NaN
# 8832       1     NaN
# 8544     NaN     NaN
# 3881     NaN     NaN
# 10136    NaN     NaN
# 5228     NaN     NaN
# 922      NaN     NaN
# 3213     NaN     NaN
# 2570     NaN     NaN
# 9358     NaN     NaN
# 3649     NaN     NaN
# 9449     NaN     NaN
# 4409     NaN     NaN
# 7748     NaN     NaN
# 9257     NaN     NaN
# 5300     NaN     NaN
# 1962     NaN     NaN
# 561      NaN     NaN
# 9773     NaN     NaN
# 9095     NaN     0.5
# 6491       1     NaN
# 8137     NaN     NaN
# 829      NaN     NaN
# 6685     NaN     0.5
# 5823     NaN     NaN

# %% [markdown]
# ## The Challenge
#
# By adding your own code in your own Jupyter Notebook cells below (you can add a cell by pressing the `+` button in the toolbar), try and answer some of the following questions about this data set:
# * How many rows are in this data set?
# * Apply some filtering to remove rows that might be incomplete or have errors. How many rows remain after your filters are applied?
# * How many atheletes are in the data set?
# * Which athlete competed in the most events?
# * How many countries are present in the data set?
# * Which country fielded the most athletes?
# * Produce a medals table showing which countries gained the most of Gold, Silver and Bronze medals.
# * What is the average age, height, and weight for each country's olympic teams?
# * As per last question, but by Male and Female athletes.
# * Finally, calculate the [Body Mass Index (BMI)](https://en.wikipedia.org/wiki/Body_mass_index) for each athlete in the data set, and display the top 10 rows for male athletes, and again for female athletes.
#
# If you comfortably work out answers for all of these, feel free to add your own analyses!

# %% [markdown]
# When you are finished:
#
# If you are running this notebook using Binder, choose **Save and Checkpoint** from the **File** menu, **rename** your notebook to add a hyphen and your initials to the notebook name e.g. `Ex08_Data_Cleaning_and_Analysis-DJ`, then choose **Download as Notebook** and save it to your computer or USB stick.
#
# If you are running this notebook on your own machine, choose **Save and Checkpoint** from the **File** menu, choose **Make a copy** from the **File** menu, then **rename** your notebook to add a hyphen and your initials to the notebook name e.g. rename from `Ex08_Data_Cleaning_and_Analysis-Copy1` to `Ex08_Data_Cleaning_and_Analysis-DJ`.

# %% [markdown]
# <sup>Copyright © David Johnson, 2018. This notebook is provided for use with permission for the Hilary Term 2019 University of Oxford course "Programming for Data Science".</sup>
